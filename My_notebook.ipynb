# %%
print("Hello World")
print(3 - 7)
# Out:
# Hello World
# -4

# %%
print (2**3) # This is 8
print (35 // 8)
print (35 % 8)
# Out:
# 8
# 4
# 3

# %%
import math
print (math.log2(8))
import statistics
print(statistics.mean([1, 7, 3, 5, 9, 1, 12]))
import statistics as stats
print(stats.mean([1, 7, 3, 5 ,9, 1 , 12]))
# Out:
# 3.0
# 5.428571428571429
# 5.428571428571429
